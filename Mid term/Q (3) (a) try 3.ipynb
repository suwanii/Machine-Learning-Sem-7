# %%
import pandas as pd
import numpy as np
from collections import Counter

# %%
df = pd.read_csv(r"C:\Users\Suwani Gunasekara\OneDrive\Documents\Sem 7 ML\Mid term\results.csv")

# %%
rank = pd.read_csv(r"C:\Users\Suwani Gunasekara\OneDrive\Documents\Sem 7 ML\Mid term\fifa_ranking-2021-05-27.csv")

# %%
rank.head()
# Out:
#         id  rank         country_full country_abrv  total_points  \
# 0    43818    82                 Iraq          IRQ            15
# 1    43873   107           Mozambique          MOZ             9
# 2    43816   108            Indonesia          IDN             9
# 3  1882218   109  Antigua and Barbuda          ATG             8
# 4    43820   110               Jordan          JOR             8
#
#    previous_points  rank_change confederation   rank_date  Year  Month
# 0                0            0           AFC  1992-12-31  1992     12
# 1                0            0           CAF  1992-12-31  1992     12
# 2                0            0           AFC  1992-12-31  1992     12
# 3                0            0      CONCACAF  1992-12-31  1992     12
# 4                0            0           AFC  1992-12-31  1992     12

# %%
newrankdate = rank['rank_date'].str.split('-',n = 3, expand = True)
rank['Year'] = newrankdate[0].astype(int)
rank['Month'] = newrankdate[1].astype(int)

# %%
rank = rank.loc[rank.Year >= 1994].reset_index()

# %%
rank = rank.sort_values(by = ['Year','country_full']).reset_index()

# %%
rank.head()
# Out:
#    level_0  index     id  rank country_full country_abrv  total_points  \
# 0       30   1025  43932    93      Albania          ALB            16
# 1      299   1294  43932    95      Albania          ALB            15
# 2      360   1355  43932    94      Albania          ALB            15
# 3      534   1529  43932    97      Albania          ALB            15
# 4      709   1704  43932   104      Albania          ALB            13
#
#    previous_points  rank_change confederation   rank_date  Year  Month
# 0               16            1          UEFA  1994-02-15  1994      2
# 1               16            2          UEFA  1994-03-15  1994      3
# 2               15            1          UEFA  1994-04-19  1994      4
# 3               15            3          UEFA  1994-05-17  1994      5
# 4               15            7          UEFA  1994-06-14  1994      6

# %%
for i in range

# %%
# Ranking for FIFA. Seems like all the FIFAs have been started on june. So I took all the ranks for month 
rankFIFA = rank.loc[(rank.Month == 6) & (rank.Year == 1994)].reset_index()

# %%
rankFIFA5 = rank.loc[(rank.Month == 5) & (rank.Year == 1994)].reset_index()

# %%
rankFIFA.shape
# Out:
# (172, 12)

# %%
newdate = df['date'].str.split('-',n = 1, expand = True)
df['Year'] = newdate[0].astype(int)

# %%
df.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral  Year
# 0  Scotland    False  1872
# 1   England    False  1873
# 2  Scotland    False  1874
# 3   England    False  1875
# 4  Scotland    False  1876

# %%
FIFA = df.loc[(df.Year >= 1992) & (df.tournament == "FIFA World Cup")]

# %%
FIFA.Year.unique()
# Out:
# array([1994, 1998, 2002, 2006, 2010, 2014, 2018])

# %%
FIFA.head()
# Out:
#              date      home_team            away_team  home_score  away_score  \
# 18383  1994-06-17        Germany              Bolivia           1           0
# 18384  1994-06-17          Spain          South Korea           2           2
# 18385  1994-06-18       Colombia              Romania           1           3
# 18386  1994-06-18          Italy  Republic of Ireland           0           1
# 18387  1994-06-18  United States          Switzerland           1           1
#
#            tournament             city        country  neutral  Year  \
# 18383  FIFA World Cup          Chicago  United States     True  1994
# 18384  FIFA World Cup           Dallas  United States     True  1994
# 18385  FIFA World Cup         Pasadena  United States     True  1994
# 18386  FIFA World Cup  East Rutherford  United States     True  1994
# 18387  FIFA World Cup          Pontiac  United States    False  1994
#
#                    TeamWon
# 18383              Germany
# ...

# %%
def teamWon(df):
    if(df['home_score']>df['away_score']):
        return df.home_team
    elif(df['home_score']<df['away_score']):
        return df.away_team
    elif(df['home_score']==df['away_score']):
        return 0

# %%
FIFA["TeamWon"] = FIFA.apply(teamWon,axis = 1)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
FIFA1994 = FIFA.loc[FIFA.Year == 1994].reset_index()

# %%
FIFA1994

# %%
FIFA1994.head()
# Out:
#    index        date      home_team            away_team  home_score  \
# 0  18383  1994-06-17        Germany              Bolivia           1
# 1  18384  1994-06-17          Spain          South Korea           2
# 2  18385  1994-06-18       Colombia              Romania           1
# 3  18386  1994-06-18          Italy  Republic of Ireland           0
# 4  18387  1994-06-18  United States          Switzerland           1
#
#    away_score      tournament             city        country  neutral  Year  \
# 0           0  FIFA World Cup          Chicago  United States     True  1994
# 1           2  FIFA World Cup           Dallas  United States     True  1994
# 2           3  FIFA World Cup         Pasadena  United States     True  1994
# 3           1  FIFA World Cup  East Rutherford  United States     True  1994
# 4           1  FIFA World Cup          Pontiac  United States    False  1994
#
#                TeamWon
# 0              Germany
# 1                    0
# ...

# %%
# getting team names
hometeamlist = list(FIFA1994.home_team.unique())
awayteamlist = list(FIFA1994.home_team.unique())
teamnames = list(set(hometeamlist+awayteamlist))

# %%
wonlist = FIFA1994.TeamWon.values.tolist()
dictwon = dict(Counter(wonlist))

# %%
homedraws = []
awaydraws = []
# appending to the list
for i in range(len(FIFA1994)):
    if FIFA1994.TeamWon[i] == 0:
        draws.append()
        homedraws.append(FIFA1994.home_team[i])
        awaydraws.append(FIFA1994.away_team[i])

# %%
draws = homedraws+awaydraws

# %%
# Creating dictionaries 
drawsdict = dict(Counter(draws))

# %%
del dictwon[0]

# %%
dictwon
# Out:
# {'Germany': 3,
#  'Romania': 3,
#  'Republic of Ireland': 1,
#  'Belgium': 2,
#  'Norway': 1,
#  'Brazil': 5,
#  'Netherlands': 3,
#  'Argentina': 2,
#  'Nigeria': 2,
#  'Switzerland': 1,
#  'United States': 1,
#  'Italy': 4,
#  'Mexico': 1,
#  'Sweden': 3,
#  'Saudi Arabia': 2,
#  'Bulgaria': 3,
#  'Colombia': 1,
#  'Spain': 2,
#  'Russia': 1}

# %%
def winCount(df,year):
    dfyear = df.loc[df.Year == year].reset_index()
    dictwon= dict(Counter(dfyear.TeamWon.values.tolist()))
    del dictwon[0]
    return pd.DataFrame(dictwon.items(),columns = ['country_full','Wins'])

# %%
FIFA94 = winCount(FIFA,1994)

# %%
FIFA94
# Out:
#            country_full  Wins
# 0               Germany     3
# 1               Romania     3
# 2   Republic of Ireland     1
# 3               Belgium     2
# 4                Norway     1
# 5                Brazil     5
# 6           Netherlands     3
# 7             Argentina     2
# 8               Nigeria     2
# 9           Switzerland     1
# 10        United States     1
# 11                Italy     4
# 12               Mexico     1
# 13               Sweden     3
# 14         Saudi Arabia     2
# 15             Bulgaria     3
# 16             Colombia     1
# 17                Spain     2
# 18               Russia     1

# %%
for index,row in rank94.iterrows():
      if row['country_full'] ==
# Out:
# _is 0
# row is country_full    Germany
# Wins                  3
# Name: 0, dtype: object
# _is 1
# row is country_full    Romania
# Wins                  3
# Name: 1, dtype: object
# _is 2
# row is country_full    Republic of Ireland
# Wins                              1
# Name: 2, dtype: object
# _is 3
# row is country_full    Belgium
# Wins                  2
# Name: 3, dtype: object
# _is 4
# row is country_full    Norway
# Wins                 1
# Name: 4, dtype: object
# _is 5
# row is country_full    Brazil
# Wins                 5
# Name: 5, dtype: object
# _is 6
# row is country_full    Netherlands
# Wins                      3
# Name: 6, dtype: object
# _is 7
# row is country_full    Argentina
# Wins                    2
# Name: 7, dtype: object
# _is 8
# row is country_full    Nigeria
# Wins                  2
# Name: 8, dtype: object
# _is 9
# row is country_full    Switzerland
# Wins                      1
# Name: 9, dtype: object
# _is 10
# ...

# %%
#rank94 = rank.loc[(rank.Year == 1994) & ((rank.Month == 6)| (rank.Month == 5))].reset_index()
rank94 = rank.loc[(rank.Year == 1994)].reset_index()

# %%
#rank94.to_csv(r"C:\Users\Suwani Gunasekara\OneDrive\Documents\Sem 7 ML\Mid term\rank94.csv")

# %%
# i think i have to get the rank of the month FIFA held in that year
all1 = FIFA94.merge(rank94, how = "inner", on ='country_full' )

# %%
all1
# Out:
#     country_full  Wins  index     id  rank country_abrv  total_points  \
# 0        Germany     3    996  43948     1          GER            59
# 1        Germany     3   1328  43948     1          GER            59
# 2        Germany     3   1453  43948     2          GER            59
# 3        Germany     3   1607  43948     2          GER            59
# 4        Germany     3   1797  43948     1          GER            60
# ..           ...   ...    ...    ...   ...          ...           ...
# 175       Russia     1   1957  43965    19          RUS            52
# 176       Russia     1   2138  43965    17          RUS            52
# 177       Russia     1   2307  43965    14          RUS            54
# 178       Russia     1   2482  43965    12          RUS            54
# 179       Russia     1   2660  43965    13          RUS            54
#
#      previous_points  rank_change confederation   rank_date  Year  Month
# ...

# %%
for index,row in all1.iterrows():
    if all1.Month == 6:

# %%
def rankCombine(df,year):
    dfyear = df.loc[df.Year == year].reset_index()
# Out:
# {'Spain': 1,
#  'United States': 1,
#  'Cameroon': 1,
#  'Germany': 1,
#  'South Korea': 1,
#  'Brazil': 2,
#  'Republic of Ireland': 1,
#  'Italy': 1,
#  'Mexico': 1,
#  'Romania': 1}

# %%
def winCount(df):
    wonlist = df.TeamWon.values.tolist()
    dictwon = dict(Counter(wonlist))

# %%
df1 = FIFA.groupby(['Year','home_team'])

# %%
FIFA.Year.values
# Out:
# array([1994, 1994, 1994, 1994, 1994, 1994, 1994, 1994, 1994, 1994, 1994,
#        1994, 1994, 1994, 1994, 1994, 1994, 1994, 1994, 1994, 1994, 1994,
#        1994, 1994, 1994, 1994, 1994, 1994, 1994, 1994, 1994, 1994, 1994,
#        1994, 1994, 1994, 1994, 1994, 1994, 1994, 1994, 1994, 1994, 1994,
#        1994, 1994, 1994, 1994, 1994, 1994, 1994, 1994, 1998, 1998, 1998,
#        1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998,
#        1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998,
#        1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998,
#        1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998,
#        1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998, 1998,
#        1998, 1998, 1998, 1998, 1998, 1998, 2002, 2002, 2002, 2002, 2002,
#        2002, 2002, 2002, 2002, 2002, 2002, 2002, 2002, 2002, 2002, 2002,
#        2002, 2002, 2002, 2002, 2002, 2002, 2002, 2002, 2002, 2002, 2002,
# ...
