# %% [markdown]
# The dataset contains 9358 instances of hourly averaged responses from an array of 5 metal oxide chemical sensors embedded in an Air Quality Chemical Multisensor Device. The device was located on the field in a significantly polluted area, at road level,within an Italian city. Data were recorded from March 2004 to February 2005 (one year)representing the longest freely available recordings of on field deployed air quality chemical sensor devices responses. Ground Truth hourly averaged concentrations for CO, Non Metanic Hydrocarbons, Benzene, Total Nitrogen Oxides (NOx) and Nitrogen Dioxide (NO2) and were provided by a co-located reference certified analyzer. Evidences of cross-sensitivities as well as both concept and sensor drifts are present as described in De Vito et al., Sens. And Act. B, Vol. 129,2,2008 (citation required) eventually affecting sensors concentration estimation capabilities. Missing values are tagged with -200 value.
# This dataset can be used exclusively for research purposes. Commercial purposes are fully excluded.

# %%
import pandas as pd
import datetime

# %%
df= pd.read_excel(r"E:\Uni\SEM 5\In17-S5-DA3110 - Data Wrangling\Project\Datasets\original.xlsx")
df.head()
# Out:
#         Date      Time Location Location Code  CO(GT)  PT08.S1(CO)  NMHC(GT)  \
# 0 2004-03-10  18:00:00  Albania           Alb     2.6      1360.00     150.0
# 1 2004-03-10  19:00:00  Albania           Alb     2.0      1292.25     112.0
# 2 2004-03-10  20:00:00  Albania           Alb     2.2      1402.00      88.0
# 3 2004-03-10  21:00:00  Albania           Alb     2.2      1375.50      80.0
# 4 2004-03-10  22:00:00  Albania           Alb     1.6      1272.25      51.0
#
#     C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0  11.881723        1045.50    166.0       1056.25    113.0       1692.00
# 1   9.397165         954.75    103.0       1173.75     92.0       1558.75
# 2   8.997817         939.25    131.0       1140.00    114.0       1554.50
# 3   9.228796         948.25    172.0       1092.00    122.0       1583.75
# 4   6.518224         835.50    131.0       1205.00    116.0       1490.00
#
#    PT08.S5(O3)   T         RH        AH
# ...

# %%
df.shape
# Out:
# (9357, 17)

# %%
df.duplicated(subset=None, keep='first').sum()
# Out:
# 0

# %%
df= pd.read_csv(r"E:\Uni\SEM 5\In17-S5-DA3110 - Data Wrangling\Project\Datasets\Air_2.csv")
df.head()
# Out:
#          Date  Hour Location Location Code  CO(GT)  PT08.S1(CO)  NMHC(GT)  \
# 0  2004-03-10    18  Albania           Alb     2.6      1360.00     150.0
# 1  2004-03-10    19  Albania           Alb     2.0      1292.25     112.0
# 2  2004-03-10    20  Albania           Alb     2.2      1402.00      88.0
# 3  2004-03-10    21  Albania           Alb     2.2      1375.50      80.0
# 4  2004-03-10    22  Albania           Alb     1.6      1272.25      51.0
#
#     C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  ...  PT08.S4(NO2)  PT08.S5(O3)   T  \
# 0  11.881723        1045.50    166.0  ...       1692.00      1267.50 NaN
# 1   9.397165         954.75    103.0  ...       1558.75       972.25 NaN
# 2   8.997817         939.25    131.0  ...       1554.50      1074.00 NaN
# 3   9.228796         948.25    172.0  ...       1583.75      1203.25 NaN
# 4   6.518224         835.50    131.0  ...       1490.00      1110.00 NaN
#
#           RH        AH  Year  Month  Day   Day_name  Day_num
# ...

# %%
df1=df.drop(['Location', 'Location Code'], axis = 1) 
df1.head()
# Out:
#          Date  Hour  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  PT08.S2(NMHC)  \
# 0  2004-03-10    18     2.6      1360.00     150.0  11.881723        1045.50
# 1  2004-03-10    19     2.0      1292.25     112.0   9.397165         954.75
# 2  2004-03-10    20     2.2      1402.00      88.0   8.997817         939.25
# 3  2004-03-10    21     2.2      1375.50      80.0   9.228796         948.25
# 4  2004-03-10    22     1.6      1272.25      51.0   6.518224         835.50
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)   T         RH  \
# 0    166.0       1056.25    113.0       1692.00      1267.50 NaN  48.875001
# 1    103.0       1173.75     92.0       1558.75       972.25 NaN  47.700000
# 2    131.0       1140.00    114.0       1554.50      1074.00 NaN  53.975000
# 3    172.0       1092.00    122.0       1583.75      1203.25 NaN  60.000000
# 4    131.0       1205.00    116.0       1490.00      1110.00 NaN  59.575001
#
#          AH  Year  Month  Day
# ...

# %%
df1.isnull().sum()
# Out:
# Date                0
# Hour                0
# CO(GT)           1683
# PT08.S1(CO)       367
# NMHC(GT)         8444
# C6H6(GT)          366
# PT08.S2(NMHC)     376
# NOx(GT)          1639
# PT08.S3(NOx)      366
# NO2(GT)          1642
# PT08.S4(NO2)      366
# PT08.S5(O3)       366
# T                6397
# RH                366
# AH                366
# Year                0
# Month               0
# Day                 0
# dtype: int64

# %%
percent_missing = df1.isnull().sum() * 100 / len(df1)
missing_value_df1 = pd.DataFrame({'percent_missing': percent_missing})
missing_value_df1.sort_values('percent_missing', inplace=True)
missing_value_df1
# Out:
#                percent_missing
# Date                  0.000000
# Year                  0.000000
# Month                 0.000000
# Day                   0.000000
# Hour                  0.000000
# C6H6(GT)              3.911510
# PT08.S4(NO2)          3.911510
# PT08.S5(O3)           3.911510
# RH                    3.911510
# AH                    3.911510
# PT08.S3(NOx)          3.911510
# PT08.S1(CO)           3.922197
# PT08.S2(NMHC)         4.018382
# NOx(GT)              17.516298
# NO2(GT)              17.548360
# CO(GT)               17.986534
# T                    68.365929
# NMHC(GT)             90.242599

# %% [markdown]
# Drop NMHC(GT) as it contains 90% null values.

# %%
df1 = df1.drop(['NMHC(GT)'],axis=1)
df1.head()
# Out:
#          Date  Hour  CO(GT)  PT08.S1(CO)   C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0  2004-03-10    18     2.6      1360.00  11.881723        1045.50    166.0
# 1  2004-03-10    19     2.0      1292.25   9.397165         954.75    103.0
# 2  2004-03-10    20     2.2      1402.00   8.997817         939.25    131.0
# 3  2004-03-10    21     2.2      1375.50   9.228796         948.25    172.0
# 4  2004-03-10    22     1.6      1272.25   6.518224         835.50    131.0
#
#    PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)   T         RH        AH  \
# 0       1056.25    113.0       1692.00      1267.50 NaN  48.875001  0.757754
# 1       1173.75     92.0       1558.75       972.25 NaN  47.700000  0.725487
# 2       1140.00    114.0       1554.50      1074.00 NaN  53.975000  0.750239
# 3       1092.00    122.0       1583.75      1203.25 NaN  60.000000  0.786713
# 4       1205.00    116.0       1490.00      1110.00 NaN  59.575001  0.788794
#
#    Year  Month  Day
# 0  2004      3   10
# ...

# %%
df1.shape
# Out:
# (9357, 17)

# %%
month=list(df1["Month"])

# %%
def getSeason(month):
    if (month == 12 or month == 1 or month == 2 ):
       return "WINTER"
    elif(month == 4 or month == 5 or month==3):
       return "SPRING"
    elif(month ==6 or month==7 or month == 8 ):
       return "SUMMER"
    else:
       return "FALL"

# %%
df1["Season"]=list(map(getSeason,month))

# %%
df1.to_csv(r"E:\Uni\SEM 5\In17-S5-DA3110 - Data Wrangling\Project\Datasets\original_2.CSV")
df1['Season']
# Out:
# 0       SPRING
# 1       SPRING
# 2       SPRING
# 3       SPRING
# 4       SPRING
# 5       SPRING
# 6       SPRING
# 7       SPRING
# 8       SPRING
# 9       SPRING
# 10      SPRING
# 11      SPRING
# 12      SPRING
# 13      SPRING
# 14      SPRING
# 15      SPRING
# 16      SPRING
# 17      SPRING
# 18      SPRING
# 19      SPRING
# 20      SPRING
# 21      SPRING
# 22      SPRING
# 23      SPRING
# 24      SPRING
# 25      SPRING
# 26      SPRING
# 27      SPRING
# 28      SPRING
# 29      SPRING
#          ...
# 9327    SPRING
# 9328    SPRING
# 9329    SPRING
# 9330    SPRING
# 9331    SPRING
# 9332    SPRING
# 9333    SPRING
# 9334    SPRING
# 9335    SPRING
# 9336    SPRING
# 9337    SPRING
# 9338    SPRING
# 9339    SPRING
# 9340    SPRING
# 9341    SPRING
# 9342    SPRING
# 9343    SPRING
# 9344    SPRING
# 9345    SPRING
# 9346    SPRING
# 9347    SPRING
# 9348    SPRING
# 9349    SPRING
# 9350    SPRING
# 9351    SPRING
# 9352    SPRING
# 9353    SPRING
# ...

# %%
df1['Season']
# Out:
# 0       SPRING
# 1       SPRING
# 2       SPRING
# 3       SPRING
# 4       SPRING
# 5       SPRING
# 6       SPRING
# 7       SPRING
# 8       SPRING
# 9       SPRING
# 10      SPRING
# 11      SPRING
# 12      SPRING
# 13      SPRING
# 14      SPRING
# 15      SPRING
# 16      SPRING
# 17      SPRING
# 18      SPRING
# 19      SPRING
# 20      SPRING
# 21      SPRING
# 22      SPRING
# 23      SPRING
# 24      SPRING
# 25      SPRING
# 26      SPRING
# 27      SPRING
# 28      SPRING
# 29      SPRING
#          ...
# 9327    SPRING
# 9328    SPRING
# 9329    SPRING
# 9330    SPRING
# 9331    SPRING
# 9332    SPRING
# 9333    SPRING
# 9334    SPRING
# 9335    SPRING
# 9336    SPRING
# 9337    SPRING
# 9338    SPRING
# 9339    SPRING
# 9340    SPRING
# 9341    SPRING
# 9342    SPRING
# 9343    SPRING
# 9344    SPRING
# 9345    SPRING
# 9346    SPRING
# 9347    SPRING
# 9348    SPRING
# 9349    SPRING
# 9350    SPRING
# 9351    SPRING
# 9352    SPRING
# 9353    SPRING
# ...

# %%
df1[['Month','Season']]
# Out:
#       Month  Season
# 0         3  SPRING
# 1         3  SPRING
# 2         3  SPRING
# 3         3  SPRING
# 4         3  SPRING
# 5         3  SPRING
# 6         3  SPRING
# 7         3  SPRING
# 8         3  SPRING
# 9         3  SPRING
# 10        3  SPRING
# 11        3  SPRING
# 12        3  SPRING
# 13        3  SPRING
# 14        3  SPRING
# 15        3  SPRING
# 16        3  SPRING
# 17        3  SPRING
# 18        3  SPRING
# 19        3  SPRING
# 20        3  SPRING
# 21        3  SPRING
# 22        3  SPRING
# 23        3  SPRING
# 24        3  SPRING
# 25        3  SPRING
# 26        3  SPRING
# 27        3  SPRING
# 28        3  SPRING
# 29        3  SPRING
# ...     ...     ...
# 9327      4  SPRING
# 9328      4  SPRING
# 9329      4  SPRING
# 9330      4  SPRING
# 9331      4  SPRING
# 9332      4  SPRING
# 9333      4  SPRING
# 9334      4  SPRING
# 9335      4  SPRING
# 9336      4  SPRING
# 9337      4  SPRING
# 9338      4  SPRING
# 9339      4  SPRING
# ...

# %%
df1.dtypes
# Out:
# Date              object
# Hour               int64
# CO(GT)           float64
# PT08.S1(CO)      float64
# C6H6(GT)         float64
# PT08.S2(NMHC)    float64
# NOx(GT)          float64
# PT08.S3(NOx)     float64
# NO2(GT)          float64
# PT08.S4(NO2)     float64
# PT08.S5(O3)      float64
# T                float64
# RH               float64
# AH               float64
# Year               int64
# Month              int64
# Day                int64
# Season            object
# dtype: object

# %% [markdown]
# Combining date and time columns and change it to datetime format

# %%
#df1["Date_Time"]=df1.apply(lambda r : pd.datetime.combine(r['Date'],r['Time']),1)
#df1

# %%
#df1= df1[['Date_Time','Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)','PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)','PT08.S5(O3)', 'T', 'RH', 'AH',]]
#df1

# %%
#df1.drop(['Time'],axis=1)

# %%
#Making a new column year, which may be useful to visualize yearly trends or year averages or measures.
#df1['Year'] = df1['Date_Time'].map(lambda x:x.year)

# %%
#df1['YearMonth'] = pd.to_datetime(df1.Date_Time).dt.to_period('m')

# %% [markdown]
# Replaces the null values of the following variables with the seasonal, daily, hourly averages.

# %%
df1["T"] = df1.groupby(["Season","Day","Hour"])["T"].transform(lambda x: x.fillna(x.mean()))
df1["CO(GT)"] = df1.groupby(["Season","Day","Hour"])["CO(GT)"].transform(lambda x: x.fillna(x.mean()))
df1["NO2(GT)"] = df1.groupby(["Season","Day","Hour"])["NO2(GT)"].transform(lambda x: x.fillna(x.mean()))
df1["NOx(GT)"] = df1.groupby(["Season","Day","Hour"])["NOx(GT)"].transform(lambda x: x.fillna(x.mean()))
df1
# Out:
#             Date  Hour  CO(GT)  PT08.S1(CO)   C6H6(GT)  PT08.S2(NMHC)  \
# 0     2004-03-10    18     2.6  1360.000000  11.881723    1045.500000
# 1     2004-03-10    19     2.0  1292.250000   9.397165     954.750000
# 2     2004-03-10    20     2.2  1402.000000   8.997817     939.250000
# 3     2004-03-10    21     2.2  1375.500000   9.228796     948.250000
# 4     2004-03-10    22     1.6  1272.250000   6.518224     835.500000
# 5     2004-03-10    23     1.2  1197.000000   4.741012     750.250000
# 6     2004-03-11     0     1.2  1185.000000   3.624399     689.500000
# 7     2004-03-11     1     1.0  1136.250000   3.326677     672.000000
# 8     2004-03-11     2     0.9  1094.000000   2.339416     608.500000
# 9     2004-03-11     3     0.6  1009.750000   1.696658     560.750000
# 10    2004-03-11     4     NaN  1011.000000   1.293620     526.750000
# 11    2004-03-11     5     0.7  1066.000000   1.133431     512.000000
# ...

# %%
df1.isnull().sum()
# Out:
# Date                0
# Hour                0
# CO(GT)             62
# PT08.S1(CO)       367
# C6H6(GT)          366
# PT08.S2(NMHC)     376
# NOx(GT)           290
# PT08.S3(NOx)      366
# NO2(GT)           290
# PT08.S4(NO2)      366
# PT08.S5(O3)       366
# T                3805
# RH                366
# AH                366
# Year                0
# Month               0
# Day                 0
# Season              0
# dtype: int64

# %% [markdown]
# There are still null values in the dataset after filling it with the mean. The reason is there are Nan values in the particular days and hour corresponding to the gas concentrations. Therefore, we are taking the previous day concentration of gas and replace it to the missing value as it a hourly data and so it's relevant.

# %%
df1.fillna(method='bfill', inplace= True)

# %%
df1.isnull().sum()
# Out:
# Date             0
# Hour             0
# CO(GT)           0
# PT08.S1(CO)      0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# Year             0
# Month            0
# Day              0
# Season           0
# dtype: int64

# %%
#df1.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
#df1.head()

# %%
#df1.isnull().sum()

# %%
df1.shape
# Out:
# (9357, 18)

# %%
df1.to_csv(r'E:\Uni\SEM 5\In17-S5-DA3110 - Data Wrangling\DW_Cleaning_1.csv')

# %% [markdown]
# # Descriptive Analysis https://medium.com/@grover.jatin/predict-car-gas-mileage-machine-learning-regression-prediction-problem-675869517617

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(x=df1['CO(GT)'])
plt.show()
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
a= (df1 < (Q1 - 1.5 * IQR)) |(df1> (Q3 + 1.5 * IQR))
a
# Out:
# Hour              13.000000
# CO(GT)             1.800000
# PT08.S1(CO)      294.375000
# NMHC(GT)         230.000000
# C6H6(GT)           9.551536
# PT08.S2(NMHC)    382.000000
# NOx(GT)          228.000000
# PT08.S3(NOx)     311.375000
# NO2(GT)           64.000000
# PT08.S4(NO2)     446.875000
# PT08.S5(O3)      542.000000
# T                  8.068750
# RH                26.687501
# AH                 0.576932
# Year               0.000000
# Month              6.000000
# Day               15.000000
# dtype: float64
#          AH  C6H6(GT)  CO(GT)   Date    Day  Day_name   Hour  Month  NMHC(GT)  \
# 0     False     False   False  False  False     False  False  False     False
# 1     False     False   False  False  False     False  False  False     False
# 2     False     False   False  False  False     False  False  False     False
# 3     False     False   False  False  False     False  False  False     False
# ...

# %%
df1.describe()
# Out:
#               Hour       CO(GT)  PT08.S1(CO)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean     11.498557     2.104262  1103.261640    10.167377     941.590547
# std       6.923182     1.428784   219.939329     7.535855     269.039673
# min       0.000000     0.100000   647.250000     0.149048     383.250000
# 25%       5.000000     1.000000   936.750000     4.434582     734.250000
# 50%      11.000000     1.800000  1068.750000     8.301413     911.500000
# 75%      18.000000     2.800000  1241.500000    14.274696    1125.500000
# max      23.000000    11.900000  2039.750000    63.741476    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    240.932076    832.651322   110.176235   1453.455417  1034.456485
# std     207.426521    257.873913    47.884515    341.117185   409.193822
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
import seaborn as sns
rcParams['figure.figsize']=10,8
#Use heatmap to see corelation between variables
sns.heatmap(df1.corr(),annot=True,cmap='viridis')
plt.title('Heatmap of co-relation between variables',fontsize=16)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(df1['CO(GT)'],['NOx(GT)'])
ax.set_xlabel('Proportion of non-retail business acres per town')
ax.set_ylabel('Full-value property-tax rate per $10,000')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-b0d8f0804431> in <module>
#       1 fig, ax = plt.subplots(figsize=(16,8))
# ----> 2 ax.scatter(df1['CO(GT)'],['NOx(GT)'])
#       3 ax.set_xlabel('Proportion of non-retail business acres per town')
#       4 ax.set_ylabel('Full-value property-tax rate per $10,000')
#       5 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
# ...

# %%
df2 = pd.DataFrame(np.random.randn(100, 3))

from scipy import stats

df2[(np.abs(stats.zscore(df2)) < 3).all(axis=1)]
# Out:
#            0         1         2
# 0   0.923505  1.214698  1.774926
# 1   0.277471 -0.277601  1.450927
# 2   0.615834  0.413756  0.516797
# 3  -0.279898 -1.018962 -0.015081
# 4   0.415928  0.983555  0.722578
# 5  -0.405865 -0.113333  1.181802
# 6  -2.613972  2.487970  1.153045
# 7  -0.112922 -0.558462  0.421984
# 8   0.890499  0.335564  0.481409
# 9  -0.259724  0.226666 -0.686080
# 11  0.261247 -0.665454  0.459554
# 12 -0.011297  1.104574  0.339554
# 13 -0.345787 -1.131677  1.720053
# 14 -0.547668  0.078228  0.435337
# 15  0.629499  0.873369  1.544340
# 16 -0.203708  0.872968 -1.494147
# 17  0.529022  1.296444 -1.429584
# 18  0.204516  0.588502  0.330515
# 19 -0.004424 -0.038975  0.202985
# 20 -0.796309 -2.016754 -0.110285
# 21 -1.123145  2.138117 -0.579227
# 22  0.641500  0.274709 -0.659202
# 23  0.291491 -0.549101 -0.697134
# 24  0.719387  0.537072  1.087206
# 25  1.367010 -0.145241 -0.335929
# 26 -1.571893 -0.234954 -0.316210
# 27 -0.453193  1.667449 -0.448926
# ...

# %%
def remove_outlier(df_in, col_name):
    q1 = df_in[col_name].quantile(0.25)
    q3 = df_in[col_name].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_out = df_in.loc[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
    return df_out

# %%
remove_outlier(df1,'CO(GT)')
# Out:
#            Date  Hour  CO(GT)  PT08.S1(CO)   C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0     3/10/2004    18     2.6  1360.000000  11.881723    1045.500000    166.0
# 1     3/10/2004    19     2.0  1292.250000   9.397165     954.750000    103.0
# 2     3/10/2004    20     2.2  1402.000000   8.997817     939.250000    131.0
# 3     3/10/2004    21     2.2  1375.500000   9.228796     948.250000    172.0
# 4     3/10/2004    22     1.6  1272.250000   6.518224     835.500000    131.0
# 5     3/10/2004    23     1.2  1197.000000   4.741012     750.250000     89.0
# 6     3/11/2004     0     1.2  1185.000000   3.624399     689.500000     62.0
# 7     3/11/2004     1     1.0  1136.250000   3.326677     672.000000     62.0
# 8     3/11/2004     2     0.9  1094.000000   2.339416     608.500000     45.0
# 9     3/11/2004     3     0.6  1009.750000   1.696658     560.750000    119.5
# 10    3/11/2004     4     0.7  1011.000000   1.293620     526.750000     21.0
# ...

# %% [markdown]
# # Fitting a regression modelfrom pandas import DataFrame

# %%
from pandas import DataFrame
from sklearn import linear_model
import statsmodels.api as sm

df = DataFrame(Stock_Market,columns=['Year','Month','Interest_Rate','Unemployment_Rate','Stock_Index_Price'])

X = df[['Interest_Rate','Unemployment_Rate']] # here we have 2 variables for multiple regression. If you just want to use one variable for simple linear regression, then use X = df['Interest_Rate'] for example.Alternatively, you may add additional variables within the brackets
Y = df['Stock_Index_Price']
 
# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

# prediction with sklearn
New_Interest_Rate = 2.75
New_Unemployment_Rate = 5.3
print ('Predicted Stock Index Price: \n', regr.predict([[New_Interest_Rate ,New_Unemployment_Rate]]))

# with statsmodels
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
